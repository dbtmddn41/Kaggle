# %%
import pandas as pd
sub = pd.read_csv('/kaggle/input/llm-prompt-recovery/sample_submission.csv')

prompt = prompt = "Please improve this text using the writing style with maintaining the original meaning but altering the tone." 
sub["rewrite_prompt"] = prompt

# %%
sub

# %%
sub.to_csv('submission.csv', index=False)
